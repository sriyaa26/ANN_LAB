# %% [markdown]
# <a href="https://colab.research.google.com/github/sriyaa26/ANN_LAB/blob/main/notebooks/linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def linear(x):
  return x

x=np.linspace(-10,10,50)

plt.figure(figsize=(10,10))
plt.plot(x,linear(x))
plt.title('Linear function')
# Out:
# Text(0.5, 1.0, 'Linear function')

# %%
import numpy as np
import matplotlib.pyplot as plt
def linear(x):
  return x
  def sigmoid(x):
    return 1/(1+np.exp(-x))
    plt.show()
  x=np.linspace(-10,10,50)
  plt.figure(figsize=(10,10))
  plt.subplot(4,2,1)
  plt.plot(x,linear(x))
  plt.title('Linear')
